# %%
# !pip install numpy
# !pip install pandas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\91987\Downloads\cricketers.csv", header = 1)
import os
cd = os.getcwd()
print(cd)
# Out:
# C:\Users\91987\Downloads

# %% [markdown]
# # Observing the data

# %%
data.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0    4s  6s
# 0  58.60   29  13  7  626+   6
# 1  91.76    4   7  1   141  23
# 2  55.68    5   4  2   186   5
# 3  54.48    7  11  1  246+  11
# 4  56.00   10   5  2  104+   1

# %%
data.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
data.rename(columns = {'Mat':"Matches",'NO' : 'Not_Out',"HS":'Highest_score','BF':'Balls_faced','SR':'Strike_Rate'},inplace = True)

# %% [markdown]
# # check null values

# %%
data.isnull().sum()
# Out:
# Player           0
# Span             0
# Matches          0
# Inns             0
# Not_Out          0
# Runs             0
# Highest_score    0
# Ave              0
# Balls_faced      3
# Strike_Rate      0
# 100              0
# 50               0
# 0                0
# 4s               0
# 6s               0
# dtype: int64

# %%
data[data['Balls_faced'].isnull()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Out  Runs  \
# 9         ED Weekes (WI)  1948-1958       48    81        5  4455
# 17       CL Walcott (WI)  1948-1960       44    74        7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33        4  1415
#
#    Highest_score    Ave Balls_faced  Strike_Rate  100  50  0    4s  6s
# 9            207  58.61         NaN          0.0   15  19  6  258+   2
# 17           220  56.68         NaN          0.0   15  14  1  107+  11
# 58          144*  48.79         NaN          0.0    5   6  3   51+   0

# %%
data['Balls_faced'] = data['Balls_faced'].fillna(0)

# %%
data[data['Balls_faced'].isnull()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Out, Runs, Highest_score, Ave, Balls_faced, Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %% [markdown]
# # drop duplicate rows

# %%
data.duplicated().sum()
# Out:
# 4

# %%
data[data.duplicated()]
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs Highest_score  \
# 5   GA Headley (WI)  1930-1954       22    40        4  2190          270*
# 12   GS Sobers (WI)  1954-1974       93   160       21  8032          365*
# 16   JB Hobbs (ENG)  1908-1930       61   102        7  5410           211
# 54    V Kohli (IND)  2011-2024      113   191       11  8848          254*
#
#       Ave Balls_faced  Strike_Rate  100  50   0    4s   6s
# 5   60.83        416+        56.00   10   5   2  104+    1
# 12  57.78       4063+        53.58   26  30  12  593+  32+
# 16  56.94       5363+        46.22   15  28   4  276+    8
# 54  49.15       15924        55.56   29  30  14   991   26

# %%
data = data.drop_duplicates()

# %% [markdown]
# # split up span into start and end date

# %%
data['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 6     [1924, 1935]
# 7     [1931, 1939]
# 8     [1955, 1968]
# 9     [1948, 1958]
# 10    [1927, 1947]
# 11    [1954, 1974]
# 13    [2000, 2015]
# 14    [2010, 2024]
# 15    [1908, 1930]
# 17    [1948, 1960]
# 18    [1937, 1955]
# 19    [1995, 2013]
# 20    [1921, 1929]
# 21    [2010, 2024]
# 22    [1968, 1973]
# 23    [1993, 1995]
# 24    [1970, 1984]
# 25    [1935, 1951]
# 26    [1989, 2013]
# 27    [1990, 2006]
# 28    [1976, 1993]
# 29    [1996, 2012]
# 30    [1998, 2010]
# 31    [2000, 2017]
# 32    [1995, 2012]
# 33    [1920, 1929]
# 34    [1992, 2002]
# 35    [2005, 2013]
# 36    [1994, 2015]
# 37    [1971, 1987]
# 38    [1985, 2004]
# 39    [1994, 2009]
# 40    [2004, 2018]
# 41    [1978, 1994]
# 42    [2019, 2024]
# 43    [1974, 1991]
# 44    [1937, 1957]
# 45    [1997, 2014]
# 46    [2012, 2024]
# 47    [1992, 2007]
# 48    [2018, 2024]
# 49    [1948, 1963]
# ...

# %%
data['Rookie_year'] = data['Span'].str.split(pat = '-').str[0]

# %%
data['Final_year'] = data['Span'].str.split(pat = '-').str[1]

# %%
data.head()
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs Highest_score  \
# 0  DG Bradman (AUS)  1928-1948       52    80       10  6996           334
# 1    HC Brook (ENG)  2022-2023       12    20        1  1181           186
# 2    AC Voges (AUS)  2015-2016       20    31        7  1485          269*
# 3   RG Pollock (SA)  1963-1970       23    41        4  2256           274
# 4   GA Headley (WI)  1930-1954       22    40        4  2190          270*
#
#      Ave Balls_faced  Strike_Rate  100  50  0    4s  6s Rookie_year Final_year
# 0  99.94       9800+        58.60   29  13  7  626+   6        1928       1948
# 1  62.15        1287        91.76    4   7  1   141  23        2022       2023
# 2  61.87        2667        55.68    5   4  2   186   5        2015       2016
# 3  60.97       1707+        54.48    7  11  1  246+  11        1963       1970
# 4  60.83        416+        56.00   10   5  2  104+   1        1930       1954

# %%
data = data.drop('Span', axis = 1)
data.head()
# Out:
#              Player  Matches  Inns  Not_Out  Runs Highest_score    Ave  \
# 0  DG Bradman (AUS)       52    80       10  6996           334  99.94
# 1    HC Brook (ENG)       12    20        1  1181           186  62.15
# 2    AC Voges (AUS)       20    31        7  1485          269*  61.87
# 3   RG Pollock (SA)       23    41        4  2256           274  60.97
# 4   GA Headley (WI)       22    40        4  2190          270*  60.83
#
#   Balls_faced  Strike_Rate  100  50  0    4s  6s Rookie_year Final_year
# 0       9800+        58.60   29  13  7  626+   6        1928       1948
# 1        1287        91.76    4   7  1   141  23        2022       2023
# 2        2667        55.68    5   4  2   186   5        2015       2016
# 3       1707+        54.48    7  11  1  246+  11        1963       1970
# 4        416+        56.00   10   5  2  104+   1        1930       1954

# %% [markdown]
# # split up country from th player name

# %%
data['Country'] =  data['Player'].str.split(pat = '(').str[1]

# %%
data['Country'] =  data['Country'].str.split(pat = ')').str[0]

# %%
data['Country']
# Out:
# 0         AUS
# 1         ENG
# 2         AUS
# 3          SA
# 4          WI
# 6         ENG
# 7         ENG
# 8         ENG
# 9          WI
# 10        ENG
# 11         WI
# 13         SL
# 14        AUS
# 15        ENG
# 17         WI
# 18        ENG
# 19     ICC/SA
# 20        ENG
# 21         NZ
# 22         WI
# 23        IND
# 24        AUS
# 25         SA
# 26        IND
# 27     ICC/WI
# 28        PAK
# 29    ICC/IND
# 30        PAK
# 31        PAK
# 32        AUS
# 33        AUS
# 34        ZIM
# 35        AUS
# 36         WI
# 37        IND
# 38        AUS
# 39        AUS
# 40         SA
# 41        AUS
# 42         NZ
# 43         WI
# 44        ENG
# 45         SL
# 46        ENG
# 47    ICC/PAK
# 48        AUS
# 49         WI
# 50        ENG
# 51    ICC/IND
# 52        PAK
# 53        IND
# 55        AUS
# 56         SA
# 57         SA
# 58        ENG
# 59         SL
# 60        AUS
# 61        AUS
# 62     ICC/SA
# 63        AUS
# 64        AUS
# 65        ENG
# ...

# %% [markdown]
# # Checking the datatypes

# %%
data.dtypes
# Out:
# Player            object
# Matches            int64
# Inns               int64
# Not_Out            int64
# Runs               int64
# Highest_score     object
# Ave              float64
# Balls_faced       object
# Strike_Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie_year       object
# Final_year        object
# Country           object
# dtype: object

# %%
data = data.astype({'Rookie_year':int,'Final_year':int})

# %%
data['Highest_score']= data['Highest_score'].str.split(pat = '*').str[0]

# %%
data.dtypes
# Out:
# Player            object
# Matches            int64
# Inns               int64
# Not_Out            int64
# Runs               int64
# Highest_score     object
# Ave              float64
# Balls_faced       object
# Strike_Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int32
# 6s                 int32
# Rookie_year        int32
# Final_year         int32
# Country           object
# dtype: object

# %%
data['4s']= data['6s'].str.split(pat = '+').str[0]
data['6s']= data['6s'].str.split(pat = '+').str[0]
data['Balls_faced']= data['Balls_faced'].str.split(pat = '+').str[0]

# %%
data = data.astype({'4s':int,'6s':int})

# %%
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#                       Player  Matches  Inns  Not_Out   Runs Highest_score  \
# 0           DG Bradman (AUS)       52    80       10   6996           334
# 1             HC Brook (ENG)       12    20        1   1181           186
# 2             AC Voges (AUS)       20    31        7   1485           269
# 3            RG Pollock (SA)       23    41        4   2256           274
# 4            GA Headley (WI)       22    40        4   2190           270
# 6          H Sutcliffe (ENG)       54    84        9   4555           194
# 7            E Paynter (ENG)       20    31        5   1540           243
# 8        KF Barrington (ENG)       82   131       15   6806           256
# 9             ED Weekes (WI)       48    81        5   4455           207
# 10          WR Hammond (ENG)       85   140       16   7249           336
# 11            GS Sobers (WI)       93   160       21   8032           365
# 13        KC Sangakkara (SL)      134   233       17  12400           319
# ...

# %%
data[data['Balls_faced'].isnull()]
# Out:
#                   Player  Matches  Inns  Not_Out  Runs Highest_score    Ave  \
# 9         ED Weekes (WI)       48    81        5  4455           207  58.61
# 17       CL Walcott (WI)       44    74        7  3798           220  56.68
# 58  Hon.FS Jackson (ENG)       20    33        4  1415           144  48.79
#
#    Balls_faced  Strike_Rate  100  50  0  4s  6s  Rookie_year  Final_year  \
# 9          NaN          0.0   15  19  6   2   2         1948        1958
# 17         NaN          0.0   15  14  1  11  11         1948        1960
# 58         NaN          0.0    5   6  3   0   0         1893        1905
#
#    Country
# 9       WI
# 17      WI
# 58     ENG

# %%
data = data.dropna(axis=0)

# %%
data[data['Balls_faced'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Out, Runs, Highest_score, Ave, Balls_faced, Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_year, Final_year, Country]
# Index: []

# %%
data = data.astype({'Balls_faced':int})

# %%
data.dtypes
# Out:
# Player            object
# Matches            int64
# Inns               int64
# Not_Out            int64
# Runs               int64
# Highest_score     object
# Ave              float64
# Balls_faced        int32
# Strike_Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int32
# 6s                 int32
# Rookie_year        int32
# Final_year         int32
# Country           object
# dtype: object

# %% [markdown]
# # Calculate average career length

# %%
data["Career_length"] = data['Final_year'] - data['Rookie_year']

# %%
data['Career_length'].mean()
# Out:
# 13.288135593220339

# %% [markdown]
# # Averge baatting strike rate for cricketers who played for more than 10 years

# %%
data[data['Career_length']>10]['Strike_Rate'].mean()
# Out:
# 50.23

# %% [markdown]
# # Find number of cricketers who played before 1960

# %%
data[data['Rookie_year'] < 1960]
# Out:
#                  Player  Matches  Inns  Not_Out  Runs Highest_score    Ave  \
# 0      DG Bradman (AUS)       52    80       10  6996           334  99.94
# 4       GA Headley (WI)       22    40        4  2190           270  60.83
# 6     H Sutcliffe (ENG)       54    84        9  4555           194  60.73
# 7       E Paynter (ENG)       20    31        5  1540           243  59.23
# 8   KF Barrington (ENG)       82   131       15  6806           256  58.67
# 10     WR Hammond (ENG)       85   140       16  7249           336  58.45
# 11       GS Sobers (WI)       93   160       21  8032           365  57.78
# 15       JB Hobbs (ENG)       61   102        7  5410           211  56.94
# 18       L Hutton (ENG)       79   138       15  6971           364  56.67
# 20   GE Tyldesley (ENG)       14    20        2   990           122  55.00
# 25       AD Nourse (SA)       34    62        7  2960           231  53.81
# ...

# %% [markdown]
# # Max Highest inn scores by country

# %%
data.groupby('Country')['Highest_score'].max().to_frame('Highinncountry').reset_index().sort_values('Highinncountry',ascending = False)
# Out:
#     Country Highinncountry
# 5    ICC/WI            400
# 0       AUS            380
# 10       SL            374
# 11       WI            365
# 1       ENG            364
# 3   ICC/PAK            329
# 2   ICC/IND            319
# 8       PAK            313
# 9        SA            278
# 4    ICC/SA            277
# 6       IND            254
# 7        NZ            251
# 12      ZIM            232

# %% [markdown]
# # Hundreds, Fifties, Duck(0) avg By country

# %%
data.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      13.000000  22.083333   4.416667
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       17.166667  28.666667   8.500000
# ZIM      12.000000  27.000000   5.000000
